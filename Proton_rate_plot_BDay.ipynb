# %%
import gps_particle_data
import wget
import os
import numpy as np 
import time
import json
import sys
import math
from datetime import datetime, timedelta
from itertools import compress


import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d = datetime(4,12,26);
print d.date

ms = gps_particle_data.meta_search();

e = gps_particle_data.event("Boxing Day Earthquake");
e.add_date(mins=59,hh=00,dd=26,mm=12,yy=04);
e.add_data("Geographic_Latitude",3.24);
e.add_data("Geographic_Longitude",95.8);

start_date = datetime(4,12,19);
end_date = datetime(5,1,16);

ms.load_data(start_date,end_date);
ms.apply_search(e, 21);
#ms.extend_time_window(15);

output_data = ms.get_selected_data("decimal_day");
# Out:
# <built-in method date of datetime.datetime object at 0x7f54507d15a8>
# File ns41_041219_v1.03.ascii already exists
#
# Reading file ns41_041219_v1.03.ascii
#
# Min Latitude         :  -56.1881
# Max Latitude         :  56.1904
# Min Longitude         :  -179.9404
# Max Longitude         :  177.8825
# Min Radius         :  4.161329
# Max Radius         :  4.176166
# Min L Shell         :  4.118633
# Max L Shell        :  25.0
# Min Day            :  354.000683
# Max Day            :  360.997905
# Year             :  2004.0
#
# File ns41_041226_v1.03.ascii already exists
#
# Reading file ns41_041226_v1.03.ascii
#
# Min Latitude         :  -179.2694
# Max Latitude         :  178.2377
# Min Longitude         :  -179.5841
# Max Longitude         :  178.1846
# Min Radius         :  1.3833
# Max Radius         :  7185.471
# Min L Shell         :  1.959381
# Max L Shell        :  25.0
# Min Day            :  361.000683
# Max Day            :  -31.9926
# Year             :  2004.0
#
# File ns41_050102_v1.03.ascii already exists
#
# Reading file ns41_050102_v1.03.ascii
#
# Min Latitude         :  -56.1907
# Max Latitude         :  56.188
# Min Longitude         :  -179.2171
# Max Longitude         :  178.5725
# Min Radius         :  4.16121
# Max Radius         :  4.176293
# Min L Shell         :  4.134035
# Max L Shell        :  25.0
# Min Day            :  2.000683
# Max Day            :  8.997905
# Year             :  2005.0
#
# File ns41_050109_v1.03.ascii already exists
#
# Reading file ns41_050109_v1.03.ascii
#
# Min Latitude         :  -56.1884
# Max Latitude         :  56.1906
# Min Longitude         :  -178.8784
# Max Longitude         :  178.9039
# Min Radius         :  4.161195
# Max Radius         :  4.176308
# Min L Shell         :  4.143344
# Max L Shell        :  25.0
# Min Day            :  9.000683
# Max Day            :  15.997905
# Year             :  2005.0
#
# File ns41_050116_v1.03.ascii already exists
#
# Reading file ns41_050116_v1.03.ascii
#
# Min Latitude         :  -56.192
# Max Latitude         :  56.1938
# Min Longitude         :  -178.5367
# Max Longitude         :  179.2627
# Min Radius         :  4.161134
# Max Radius         :  4.176381
# Min L Shell         :  4.153831
# Max L Shell        :  25.0
# Min Day            :  16.000683
# Max Day            :  22.997905
# Year             :  2005.0
#
# File ns41_050123_v1.03.ascii already exists
#
# Reading file ns41_050123_v1.03.ascii
# Downloading ns48_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns53_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# File ns54_041219_v1.03.ascii already exists
#
# Reading file ns54_041219_v1.03.ascii
#
# Min Latitude         :  -55.1507
# Max Latitude         :  55.1522
# Min Longitude         :  -177.9506
# Max Longitude         :  179.717
# Min Radius         :  4.145722
# Max Radius         :  4.191869
# Min L Shell         :  4.149375
# Max L Shell        :  999.0
# Min Day            :  354.000405
# Max Day            :  360.997627
# Year             :  2004.0
#
# File ns54_041226_v1.03.ascii already exists
#
# Reading file ns54_041226_v1.03.ascii
#
# Min Latitude         :  -55.1536
# Max Latitude         :  55.1524
# Min Longitude         :  -177.7553
# Max Longitude         :  179.8973
# Min Radius         :  4.145743
# Max Radius         :  4.191852
# Min L Shell         :  4.159904
# Max L Shell        :  999.0
# Min Day            :  361.000405
# Max Day            :  1.997627
# Year             :  2004.0
#
# File ns54_050102_v1.03.ascii already exists
#
# Reading file ns54_050102_v1.03.ascii
#
# Min Latitude         :  -55.1528
# Max Latitude         :  55.1512
# Min Longitude         :  -179.9791
# Max Longitude         :  179.996
# Min Radius         :  4.145771
# Max Radius         :  4.191833
# Min L Shell         :  4.204648
# Max L Shell        :  999.0
# Min Day            :  2.000405
# Max Day            :  8.997627
# Year             :  2005.0
#
# File ns54_050109_v1.03.ascii already exists
#
# Reading file ns54_050109_v1.03.ascii
#
# Min Latitude         :  -55.1539
# Max Latitude         :  55.1539
# Min Longitude         :  -179.9066
# Max Longitude         :  177.7098
# Min Radius         :  4.145727
# Max Radius         :  4.191889
# Min L Shell         :  4.170274
# Max L Shell        :  999.0
# Min Day            :  9.000405
# Max Day            :  15.997627
# Year             :  2005.0
#
# File ns54_050116_v1.03.ascii already exists
#
# Reading file ns54_050116_v1.03.ascii
#
# Min Latitude         :  -55.152
# Max Latitude         :  55.1541
# Min Longitude         :  -179.7542
# Max Longitude         :  177.8683
# Min Radius         :  4.145724
# Max Radius         :  4.191889
# Min L Shell         :  4.203447
# Max L Shell        :  999.0
# Min Day            :  16.000405
# Max Day            :  22.997627
# Year             :  2005.0
#
# File ns54_050123_v1.03.ascii already exists
#
# Reading file ns54_050123_v1.03.ascii
# Downloading ns55_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# File ns56_041219_v1.03.ascii already exists
#
# Reading file ns56_041219_v1.03.ascii
#
# Min Latitude         :  -55.055
# Max Latitude         :  55.0558
# Min Longitude         :  -179.9907
# Max Longitude         :  179.9929
# Min Radius         :  4.158766
# Max Radius         :  4.178659
# Min L Shell         :  4.1526
# Max L Shell        :  999.0
# Min Day            :  354.0011
# Max Day            :  360.998322
# Year             :  2004.0
#
# File ns56_041226_v1.03.ascii already exists
#
# Reading file ns56_041226_v1.03.ascii
#
# Min Latitude         :  -55.066
# Max Latitude         :  55.0636
# Min Longitude         :  -179.9546
# Max Longitude         :  179.6279
# Min Radius         :  4.158731
# Max Radius         :  4.178748
# Min L Shell         :  4.14888
# Max L Shell        :  999.0
# Min Day            :  361.0011
# Max Day            :  1.998322
# Year             :  2004.0
#
# File ns56_050102_v1.03.ascii already exists
#
# Reading file ns56_050102_v1.03.ascii
#
# Min Latitude         :  -55.0664
# Max Latitude         :  55.0663
# Min Longitude         :  -179.8613
# Max Longitude         :  179.7147
# Min Radius         :  4.158674
# Max Radius         :  4.178766
# Min L Shell         :  4.146496
# Max L Shell        :  999.0
# Min Day            :  2.0011
# Max Day            :  8.998322
# Year             :  2005.0
#
# File ns56_050109_v1.03.ascii already exists
#
# Reading file ns56_050109_v1.03.ascii
#
# Min Latitude         :  -55.0774
# Max Latitude         :  55.0793
# Min Longitude         :  -179.775
# Max Longitude         :  179.7973
# Min Radius         :  4.158606
# Max Radius         :  4.178905
# Min L Shell         :  4.144459
# Max L Shell        :  999.0
# Min Day            :  9.0011
# Max Day            :  15.998322
# Year             :  2005.0
#
# File ns56_050116_v1.03.ascii already exists
#
# Reading file ns56_050116_v1.03.ascii
#
# Min Latitude         :  -55.0811
# Max Latitude         :  55.08
# Min Longitude         :  -179.7095
# Max Longitude         :  179.8623
# Min Radius         :  4.158473
# Max Radius         :  4.179019
# Min L Shell         :  4.13754
# Max L Shell        :  999.0
# Min Day            :  16.0011
# Max Day            :  22.998322
# Year             :  2005.0
#
# File ns56_050123_v1.03.ascii already exists
#
# Reading file ns56_050123_v1.03.ascii
# Downloading ns57_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns58_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# File ns59_041219_v1.03.ascii already exists
#
# Reading file ns59_041219_v1.03.ascii
#
# Min Latitude         :  -54.9861
# Max Latitude         :  54.9864
# Min Longitude         :  -179.6188
# Max Longitude         :  179.2778
# Min Radius         :  4.155547
# Max Radius         :  4.181789
# Min L Shell         :  4.112859
# Max L Shell        :  999.0
# Min Day            :  354.000544
# Max Day            :  360.997766
# Year             :  2004.0
#
# File ns59_041226_v1.03.ascii already exists
#
# Reading file ns59_041226_v1.03.ascii
#
# Min Latitude         :  -54.9743
# Max Latitude         :  54.9745
# Min Longitude         :  -179.2692
# Max Longitude         :  179.6775
# Min Radius         :  4.155606
# Max Radius         :  4.181705
# Min L Shell         :  4.11735
# Max L Shell        :  999.0
# Min Day            :  361.000544
# Max Day            :  1.997766
# Year             :  2004.0
#
# File ns59_050102_v1.03.ascii already exists
# Reading file ns59_050102_v1.03.ascii
#
# Min Latitude         :  -54.9711
# Max Latitude         :  54.9696
# Min Longitude         :  -179.9653
# Max Longitude         :  179.9847
# Min Radius         :  4.155689
# Max Radius         :  4.181649
# Min L Shell         :  4.126499
# Max L Shell        :  999.0
# Min Day            :  2.000544
# Max Day            :  8.997766
# Year             :  2005.0
#
# File ns59_050109_v1.03.ascii already exists
#
# Reading file ns59_050109_v1.03.ascii
#
# Min Latitude         :  -54.9602
# Max Latitude         :  54.9599
# Min Longitude         :  -179.9163
# Max Longitude         :  178.9833
# Min Radius         :  4.155746
# Max Radius         :  4.181571
# Min L Shell         :  4.129611
# Max L Shell        :  999.0
# Min Day            :  9.000544
# Max Day            :  15.997766
# Year             :  2005.0
#
# File ns59_050116_v1.03.ascii already exists
#
# Reading file ns59_050116_v1.03.ascii
#
# Min Latitude         :  -54.9601
# Max Latitude         :  54.9582
# Min Longitude         :  -179.5363
# Max Longitude         :  179.3341
# Min Radius         :  4.15579
# Max Radius         :  4.181571
# Min L Shell         :  4.145895
# Max L Shell        :  999.0
# Min Day            :  16.000544
# Max Day            :  22.997766
# Year             :  2005.0
#
# File ns59_050123_v1.03.ascii already exists
#
# Reading file ns59_050123_v1.03.ascii
# File ns60_041219_v1.03.ascii already exists
#
# Reading file ns60_041219_v1.03.ascii
#
# Min Latitude         :  -55.1647
# Max Latitude         :  55.1649
# Min Longitude         :  -179.9964
# Max Longitude         :  179.9918
# Min Radius         :  4.153455
# Max Radius         :  4.184214
# Min L Shell         :  4.118582
# Max L Shell        :  999.0
# Min Day            :  354.0011
# Max Day            :  360.998322
# Year             :  2004.0
#
# File ns60_041226_v1.03.ascii already exists
#
# Reading file ns60_041226_v1.03.ascii
#
# Min Latitude         :  -55.1624
# Max Latitude         :  55.1623
# Min Longitude         :  -179.9928
# Max Longitude         :  179.9962
# Min Radius         :  4.15355
# Max Radius         :  4.184111
# Min L Shell         :  4.126345
# Max L Shell        :  999.0
# Min Day            :  361.0011
# Max Day            :  1.998322
# Year             :  2004.0
#
# File ns60_050102_v1.03.ascii already exists
#
# Reading file ns60_050102_v1.03.ascii
#
# Min Latitude         :  -55.1666
# Max Latitude         :  55.1665
# Min Longitude         :  -179.9323
# Max Longitude         :  179.9852
# Min Radius         :  4.153563
# Max Radius         :  4.184072
# Min L Shell         :  4.13214
# Max L Shell        :  999.0
# Min Day            :  2.0011
# Max Day            :  8.998322
# Year             :  2005.0
#
# File ns60_050109_v1.03.ascii already exists
#
# Reading file ns60_050109_v1.03.ascii
#
# Min Latitude         :  -55.1669
# Max Latitude         :  55.1669
# Min Longitude         :  -179.9973
# Max Longitude         :  179.9931
# Min Radius         :  4.15356
# Max Radius         :  4.184071
# Min L Shell         :  4.140262
# Max L Shell        :  999.0
# Min Day            :  9.0011
# Max Day            :  15.998322
# Year             :  2005.0
#
# File ns60_050116_v1.03.ascii already exists
#
# Reading file ns60_050116_v1.03.ascii
#
# Min Latitude         :  -55.1707
# Max Latitude         :  55.1707
# Min Longitude         :  -179.9163
# Max Longitude         :  179.9827
# Min Radius         :  4.153599
# Max Radius         :  4.18404
# Min L Shell         :  4.167293
# Max L Shell        :  999.0
# Min Day            :  16.0011
# Max Day            :  22.998322
# Year             :  2005.0
#
# File ns60_050123_v1.03.ascii already exists
#
# Reading file ns60_050123_v1.03.ascii
# File ns61_041219_v1.03.ascii already exists
#
# Reading file ns61_041219_v1.03.ascii
#
# Min Latitude         :  -54.8537
# Max Latitude         :  54.8541
# Min Longitude         :  -179.4096
# Max Longitude         :  178.8359
# Min Radius         :  4.129252
# Max Radius         :  4.208162
# Min L Shell         :  4.16317
# Max L Shell        :  999.0
# Min Day            :  354.002211
# Max Day            :  360.999433
# Year             :  2004.0
#
# File ns61_041226_v1.03.ascii already exists
#
# Reading file ns61_041226_v1.03.ascii
#
# Min Latitude         :  -54.8374
# Max Latitude         :  54.8372
# Min Longitude         :  -178.8904
# Max Longitude         :  179.308
# Min Radius         :  4.129246
# Max Radius         :  4.208173
# Min L Shell         :  4.158194
# Max L Shell        :  999.0
# Min Day            :  361.002211
# Max Day            :  1.999433
# Year             :  2004.0
#
# File ns61_050102_v1.03.ascii already exists
#
# Reading file ns61_050102_v1.03.ascii
#
# Min Latitude         :  -54.8374
# Max Latitude         :  54.8371
# Min Longitude         :  -178.7977
# Max Longitude         :  179.3989
# Min Radius         :  4.129246
# Max Radius         :  4.208173
# Min L Shell         :  4.160876
# Max L Shell        :  999.0
# Min Day            :  2.001794
# Max Day            :  8.999016
# Year             :  2005.0
#
# File ns61_050109_v1.03.ascii already exists
#
# Reading file ns61_050109_v1.03.ascii
#
# Min Latitude         :  -54.8358
# Max Latitude         :  54.8345
# Min Longitude         :  -178.3749
# Max Longitude         :  179.8436
# Min Radius         :  4.129129
# Max Radius         :  4.208262
# Min L Shell         :  4.157373
# Max L Shell        :  999.0
# Min Day            :  9.001794
# Max Day            :  15.999016
# Year             :  2005.0
#
# File ns61_050116_v1.03.ascii already exists
#
# Reading file ns61_050116_v1.03.ascii
#
# Min Latitude         :  -54.8245
# Max Latitude         :  54.8249
# Min Longitude         :  -179.9686
# Max Longitude         :  179.973
# Min Radius         :  4.129086
# Max Radius         :  4.208339
# Min L Shell         :  4.158446
# Max L Shell        :  999.0
# Min Day            :  16.001794
# Max Day            :  22.999016
# Year             :  2005.0
#
# File ns61_050123_v1.03.ascii already exists
#
# Reading file ns61_050123_v1.03.ascii
# Downloading ns62_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns63_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns64_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns65_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns66_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns67_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns68_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns69_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns70_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns71_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns72_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file
# Downloading ns73_041219_v1.03.ascii
#
# Check the filename as the returned file appears too small
# ... deleting file

# %%
print output_data.keys()
# Out:
# ['ns41_041219', 'ns61_041219', 'ns60_041219', 'ns59_041219', 'ns54_041226', 'ns56_041219', 'ns56_041226', 'ns61_041226', 'ns59_041226', 'ns60_041226', 'ns54_041219', 'ns41_041226']

# %%
data_index = 0;
signal = 'rate_proton_measured'
background = 'proton_background'
sat = 'ns41'
for date in ['041219', '041226', '050102', '050109', '050116']:
    filename = sat + '_' + date
    x =  output_data[filename]["decimal_day"][:]
    tmp = output_data[filename][signal][:];

    k = len(tmp[0])
    p_eng = np.array_split(tmp, range(k), axis = 1)

    colour = ['rosybrown', 'blue', 'red', 'green', 'magenta', 'navy', 'aqua', 'orange', 'yellow' , 'lime', 'peru', 'slategrey', 'teal', 'maroon', 'mediumspringgreen']
    fig = plt.figure(figsize=(8, 6), dpi=120)
    ax = fig.add_subplot(111)
    for j in range(k):
        ax.scatter(x, p_eng[j+1], color = colour[j] ,label = j)
    ax.legend(loc = 'upper left')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-ca8c9c93c07d> in <module>()
#       5 for date in ['041219', '041226', '050102', '050109', '050116']:
#       6     filename = sat + '_' + date
# ----> 7     x =  output_data[filename]["decimal_day"][:]
#       8     tmp = output_data[filename][signal][:];
#       9
#
# KeyError: 'ns41_050102'

# %%
# Out:
# ['ns59_050102', 'ns60_050109', 'ns59_050109', 'ns59_050123', 'ns60_050102', 'ns61_050102', 'ns54_050116', 'ns41_041226', 'ns61_050123', 'ns61_050109', 'ns41_050123', 'ns56_050116', 'ns41_050102', 'ns61_041226', 'ns41_050109', 'ns59_050116', 'ns54_050109', 'ns60_050116', 'ns54_050102', 'ns54_041226', 'ns54_050123', 'ns56_041226', 'ns59_041226', 'ns61_050116', 'ns56_050123', 'ns41_050116', 'ns56_050102', 'ns60_041226', 'ns56_050109', 'ns60_050123']
# 'for fn in output_data.keys():\n    print fn;\n    for ikey in output_data[fn].keys():\n        print ikey;\n        print output_data[fn][ikey][0];\n        print output_data[fn][ikey][-1];'
