# %%
import gps_particle_data
import wget
import os
import numpy as np 
import time
import json
import sys
import math
from datetime import datetime, timedelta, date
from itertools import compress
from random import randint
import urllib2
import aacgmv2
import scipy
import matplotlib
from matplotlib import gridspec
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#for i in range(11):
    #fname = 'NT_2_'+str(i)+'.ascii'
    #open(fname, 'w+')

# %%
sats = [54, 56, 59, 60, 61]
for i in range(11):
    dist_list = []
    for ns in sats:
        fname = '/home/filip/Documents/iPython/X-cor_ns' + str(ns) +'/ch2_' + str(i) + '.ascii'
        cor = np.loadtxt(fname)
        for j in cor:
            dist_list.append(j)
    fig = plt.figure(figsize=(12, 9))
    plt.hist(dist_list, bins = np.arange(min(dist_list), max(dist_list)+0.1, 0.05))
    plt.show()

# %%
#Test 25th May 2009

start_date = datetime(2009,5,20,0,0,0);
end_date = datetime(2009,5,26,0,0,0);
ms = gps_particle_data.meta_search();
ms.load_data(start_date,end_date);

#Print cross-cor coef between channel 2 and all other channels.

signal = 'rate_electron_measured'
output_data = ms.get_all_data_by_satellite()
for ns in output_data.keys():
    for i in range(11):
        #print ns, i
        a0 = np.asarray(output_data[ns][signal])[:,2]
        ar2 = np.asarray(output_data[ns][signal])[:,i]
        cor = np.correlate(a0, ar2)/(math.sqrt(np.sum(a0**2)*np.sum(ar2**2)))
        #print cor
        fname = 'NT_2_'+str(i)+'.ascii'
        with open(fname, 'a') as f:
            np.savetxt(f, cor)
            
cont = np.loadtxt('NT_2_2.ascii')
print cont
# Out:
# ====================================
# Loading data for satellite  54
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns54/ns54_090524_v1.03.ascii
#
# ====================================
# Loading data for satellite  56
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns56/ns56_090524_v1.03.ascii
#
# ====================================
# Loading data for satellite  59
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns59/ns59_090524_v1.03.ascii
#
# ====================================
# Loading data for satellite  60
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns60/ns60_090524_v1.03.ascii
#
# ====================================
# Loading data for satellite  61
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns61/ns61_090524_v1.03.ascii
# NT_2_2.ascii
# NT_2_2.ascii
# NT_2_2.ascii
# NT_2_2.ascii
# NT_2_2.ascii
# [ 1.  1.  1.  1.  1.]

# %%
#Test 25th May 2009

start_date = datetime(2009,5,20,0,0,0);
end_date = datetime(2009,5,26,0,0,0);
ms = gps_particle_data.meta_search();
ms.load_data(start_date,end_date);

signal = 'rate_electron_measured'
output_data = ms.get_all_data_by_satellite()
for ns in output_data.keys():
    for i in range(11):
        #print ns, i
        a0 = np.asarray(output_data[ns][signal])[:,2]
        ar2 = np.asarray(output_data[ns][signal])[:,i]
        cor = np.correlate(a0, ar2)/(math.sqrt(np.sum(a0**2)*np.sum(ar2**2)))
        #print cor
        fname = 'NT_2_'+str(i)+'.ascii'
        with open(fname, 'a') as f:
            np.savetxt(f, cor)
            
cont = np.loadtxt('NT_2_0.ascii')
print cont
# Out:
# ====================================
# Loading data for satellite  54
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns54/ns54_090524_v1.03.ascii
#
# ====================================
# Loading data for satellite  56
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns56/ns56_090524_v1.03.ascii
#
# ====================================
# Loading data for satellite  59
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns59/ns59_090524_v1.03.ascii
#
# ====================================
# Loading data for satellite  60
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns60/ns60_090524_v1.03.ascii
#
# ====================================
# Loading data for satellite  61
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns61/ns61_090524_v1.03.ascii
# [ 0.23554187  0.66382697  0.6594      0.09514254  0.90564443  0.23554187
#   0.66382697  0.6594      0.09514254  0.90564443]

# %%
#Test 12th Feb 2013

start_date = datetime(2013,2,9,0,0,0);
end_date = datetime(2013,2,13,0,0,0);
ms = gps_particle_data.meta_search();
ms.load_data(start_date,end_date);

signal = 'rate_electron_measured'
output_data = ms.get_all_data_by_satellite()
for ns in output_data.keys():
    for i in range(11):
        #print ns, i
        a0 = np.asarray(output_data[ns][signal])[:,2]
        ar2 = np.asarray(output_data[ns][signal])[:,i]
        cor = np.correlate(a0, ar2)/(math.sqrt(np.sum(a0**2)*np.sum(ar2**2)))
        #print cor
        fname = 'NT_2_'+str(i)+'.ascii'
        with open(fname, 'a') as f:
            np.savetxt(f, cor)
            
cont = np.loadtxt('NT_2_0.ascii')
print cont
# Out:
# ====================================
# Loading data for satellite  54
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns54/ns54_130210_v1.03.ascii
#
# ====================================
# Loading data for satellite  56
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns56/ns56_130210_v1.03.ascii
#
# ====================================
# Loading data for satellite  59
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns59/ns59_130210_v1.03.ascii
#
# ====================================
# Loading data for satellite  60
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns60/ns60_130210_v1.03.ascii
#
# ====================================
# Loading data for satellite  61
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns61/ns61_130210_v1.03.ascii
# [ 0.23554187  0.66382697  0.6594      0.09514254  0.90564443  0.23554187
#   0.66382697  0.6594      0.09514254  0.90564443  0.44425641  0.68037488
#   0.88336327  0.73421463  0.86554345]

# %%
#Test 6th Jan 2016

start_date = datetime(2016,1,2,0,0,0);
end_date = datetime(2016,1,7,0,0,0);
ms = gps_particle_data.meta_search();
ms.load_data(start_date,end_date);

signal = 'rate_electron_measured'
output_data = ms.get_all_data_by_satellite()
for ns in output_data.keys():
    for i in range(11):
        #print ns, i
        a0 = np.asarray(output_data[ns][signal])[:,2]
        ar2 = np.asarray(output_data[ns][signal])[:,i]
        cor = np.correlate(a0, ar2)/(math.sqrt(np.sum(a0**2)*np.sum(ar2**2)))
        #print cor
        fname = 'NT_2_'+str(i)+'.ascii'
        with open(fname, 'a') as f:
            np.savetxt(f, cor)
            
cont = np.loadtxt('NT_2_0.ascii')
print cont
# Out:
# ====================================
# Loading data for satellite  54
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns54/ns54_160103_v1.03.ascii
#
# ====================================
# Loading data for satellite  56
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns56/ns56_160103_v1.03.ascii
#
# ====================================
# Loading data for satellite  59
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns59/ns59_160103_v1.03.ascii
#
# ====================================
# Loading data for satellite  60
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns60/ns60_160103_v1.03.ascii
#
# ====================================
# Loading data for satellite  61
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns61/ns61_160103_v1.03.ascii
# [ 0.23554187  0.66382697  0.6594      0.09514254  0.90564443  0.23554187
#   0.66382697  0.6594      0.09514254  0.90564443  0.44425641  0.68037488
#   0.88336327  0.73421463  0.86554345  0.61118363  0.99230772  0.99314933
#   0.99035803  0.9921995 ]

# %%
#Test 9th Sept 2016

start_date = datetime(2016,9,4,0,0,0);
end_date = datetime(2016,9,10,0,0,0);
ms = gps_particle_data.meta_search();
ms.load_data(start_date,end_date);

signal = 'rate_electron_measured'
output_data = ms.get_all_data_by_satellite()
for ns in output_data.keys():
    for i in range(11):
        #print ns, i
        a0 = np.asarray(output_data[ns][signal])[:,2]
        ar2 = np.asarray(output_data[ns][signal])[:,i]
        cor = np.correlate(a0, ar2)/(math.sqrt(np.sum(a0**2)*np.sum(ar2**2)))
        #print cor
        fname = 'NT_2_'+str(i)+'.ascii'
        with open(fname, 'a') as f:
            np.savetxt(f, cor)
            
cont = np.loadtxt('NT_2_0.ascii')
print cont
# Out:
# ====================================
# Loading data for satellite  54
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns54/ns54_160904_v1.03.ascii
#
# ====================================
# Loading data for satellite  56
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns56/ns56_160904_v1.03.ascii
#
# ====================================
# Loading data for satellite  59
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns59/ns59_160904_v1.03.ascii
#
# ====================================
# Loading data for satellite  60
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns60/ns60_160904_v1.03.ascii
#
# ====================================
# Loading data for satellite  61
# File : https://www.ngdc.noaa.gov/stp/space-weather/satellite-data/satellite-systems/gps/data/ns61/ns61_160904_v1.03.ascii
# [ 0.23554187  0.66382697  0.6594      0.09514254  0.90564443  0.23554187
#   0.66382697  0.6594      0.09514254  0.90564443  0.44425641  0.68037488
#   0.88336327  0.73421463  0.86554345  0.61118363  0.99230772  0.99314933
#   0.99035803  0.9921995   0.99544243  0.9956878   0.99497016  0.99546249
#   0.99509029]

# %%
fname = 'NT_2_3.ascii'
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(111)
cor = np.loadtxt(fname)
ax.hist(dist_list, bins = np.arange(min(cor), max(cor)+0.1, 0.05), label = 'No tests')
ax.hist(cor, np.arange(min(cor), max(cor)+0.1, 0.05), color = 'red', label = 'Tests')
#plt.title(fname)
plt.xlabel('Cross-correlation coefficient', fontsize = 30)
plt.ylabel('Frequency', fontsize = 30)
plt.legend(fontsize = 'xx-large')
plt.show()

# %%
sats = [54, 56, 59, 60, 61]
for i in range(11):
    dist_list = []
    for ns in sats:
        fn = '/home/filip/Documents/iPython/X-cor_ns' + str(ns) +'/ch2_' + str(i) + '.ascii'
        cor_fn = np.loadtxt(fn)
        for j in cor_fn:
            dist_list.append(j)
    fname = 'NT_2_'+str(i)+'.ascii'
    cor_fname = np.loadtxt(fname)
    fig = plt.figure(figsize=(12, 9))
    ax = fig.add_subplot(111)
    cor = np.loadtxt(fname)
    ax.hist(dist_list, bins = np.arange(min(cor), max(cor)+0.1, 0.05), label = 'No tests')
    ax.hist(cor, np.arange(min(cor), max(cor)+0.1, 0.05), color = 'red', label = 'Tests')
    plt.title(fname)
    plt.xlabel('Cross-correlation coefficient', fontsize = 30)
    plt.ylabel('Frequency', fontsize = 30)
    plt.legend(fontsize = 'xx-large')
    plt.show()
